# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisyeung2021/CB2240_GROUP2/blob/main/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
a += 1
print(a)
# Out:
# 11

# %%
b=10
c=20
